# %% [markdown]
# Predicting baby name sex using PyTorch for Logistic Regression
#
# ### References
#
# - [Logistic Regression with PyTorch](https://proai.org/pytorch-logistic-regression) by [Denny Loevlie](https://twitter.com/DennisLoevlie)
# - [PyTorch OO design compared with SkLearn](https://jeancochrane.com/blog/pytorch-functional-api) by [Jean Cochrane](https://JeanCochrane.com)
# - [Building Your First Network in PyTorch](https://t.co/m9I4e0tfrC) by [Ta-Ying Cheng](https://www.linkedin.com/in/tim-ta-ying-cheng-411857139/)
# - [data.world US baby names since 1880](https://data.world/ssa/baby-names-for-us-states-territories)

# %%
import numpy as np
import pandas as pd
# neither year nor len are statistically significant predictors of sex
from pathlib import Path

# %%
pd.options.display.max_rows=7

# %%
CWD = Path('.').absolute().resolve()
DATA_DIR_NAME = '.nlpia2-data'
DATA_FILE = 'baby-names-region.csv.gz'
CWD
# Out:
# WindowsPath('C:/Users/maria/Dropbox/Tangible AI/gitlab/nlpia2/src/nlpia2/ch05')

# %%
parent = CWD
data_dir = parent / DATA_DIR_NAME 
filepath = data_dir / DATA_FILE
for i in range(10):
    print(filepath)
    if filepath.is_file():
        break
    parent = parent.parent
    data_dir = parent / DATA_DIR_NAME 
    filepath = data_dir / DATA_FILE
filepath
# Out:
# C:\Users\maria\Dropbox\Tangible AI\gitlab\nlpia2\src\nlpia2\ch05\.nlpia2-data\baby-names-region.csv.gz
# C:\Users\maria\Dropbox\Tangible AI\gitlab\nlpia2\src\nlpia2\.nlpia2-data\baby-names-region.csv.gz
# C:\Users\maria\Dropbox\Tangible AI\gitlab\nlpia2\src\.nlpia2-data\baby-names-region.csv.gz
# C:\Users\maria\Dropbox\Tangible AI\gitlab\nlpia2\.nlpia2-data\baby-names-region.csv.gz
# WindowsPath('C:/Users/maria/Dropbox/Tangible AI/gitlab/nlpia2/.nlpia2-data/baby-names-region.csv.gz')

# %%
def find_dir(dirname=DATA_DIR_NAME, parent=Path('.').absolute().resolve(), max_parents=20):
    for i in range(max_parents):
        data_dir = parent / dirname
        if data_dir.is_dir():
            return data_dir
        parent = parent.parent

DATA_DIR = find_dir()
DATA_DIR
# Out:
# WindowsPath('C:/Users/maria/Dropbox/Tangible AI/gitlab/nlpia2/.nlpia2-data')

# %%
def find_file(filename, parent=Path('.').absolute().resolve(), data_dir_name=DATA_DIR_NAME, max_parents=20):
    for i in range(max_parents):
        data_dir = parent / data_dir_name 
        filepath = data_dir / filename
        if filepath.is_file():
            return filepath
        parent = parent.parent

filepath = find_file(DATA_FILE)
filepath
# Out:
# WindowsPath('C:/Users/maria/Dropbox/Tangible AI/gitlab/nlpia2/.nlpia2-data/baby-names-region.csv.gz')

# %%
df = pd.read_csv(filepath)

# %%
np.random.seed(451)
df = df.sample(10_000)
df
# Out:
#         region sex  year      name  count      freq
# 6139665     WV   F  1987  Brittani     10  0.000003
# 2565339     MD   F  1954       Ida     18  0.000005
# 22297       AK   M  1988   Maxwell      5  0.000001
# ...        ...  ..   ...       ...    ...       ...
# 4475894     OK   F  1950      Leah      9  0.000003
# 5744351     VA   F  2007    Carley     11  0.000003
# 5583882     TX   M  2019   Kartier     10  0.000003
#
# [10000 rows x 6 columns]

# %%
names = df['name'].unique()
list(names[:10])
# Out:
# ['Brittani',
#  'Ida',
#  'Maxwell',
#  'Charlene',
#  'Todd',
#  'Aubrey',
#  'Arianna',
#  'Otis',
#  'Trenton',
#  'Faustino']

# %%
len(names) / len(df)
# Out:
# 0.4025

# %%
# df = pd.get_dummies(df, columns=['region'])
# df.head()

# %%
df = df.rename(dict(name='name_', sex='sex_'), axis=1)
df.head()
# Out:
#         region sex_  year     name_  count      freq
# 6139665     WV    F  1987  Brittani     10  0.000003
# 2565339     MD    F  1954       Ida     18  0.000005
# 22297       AK    M  1988   Maxwell      5  0.000001
# 5114650     TN    F  1972  Charlene     24  0.000008
# 2126395     KS    M  1954      Todd     11  0.000003

# %%
df = df.groupby(['name_', 'sex_']).sum()
df
# Out:
#              year  count      freq
# name_  sex_
# Aaden  M     2008     51  0.000015
# Aahana F     2018     26  0.000009
# Aahil  M     2019      5  0.000002
# ...           ...    ...       ...
# Zvi    M     2015      5  0.000002
# Zya    F     2019      8  0.000003
# Zylah  F     2008      5  0.000001
#
# [4238 rows x 3 columns]

# %%
df_with_duplicates = pd.read_csv(filepath)
np.random.seed(451)
df_with_duplicates = df_with_duplicates.sample(10_000)
df_with_duplicates.set_index(['name', 'sex'])
groups = df_with_duplicates.groupby(['name', 'sex'])

# %%
groups = df_with_duplicates.groupby(['name', 'sex'])
for group in groups: 
    if len(group) > 1:
        print (group)
# Out:
# (('Aaden', 'M'),         region sex  year   name  count      freq
# 1258876     FL   M  2008  Aaden     51  0.000015)
# (('Aahana', 'F'),        region sex  year    name  count      freq
# 612877     CA   F  2018  Aahana     26  0.000009)
# (('Aahil', 'M'),         region sex  year   name  count      freq
# 5584635     TX   M  2019  Aahil      5  0.000002)
# (('Aaleyah', 'F'),        region sex  year     name  count      freq
# 581605     CA   F  2010  Aaleyah     17  0.000005)
# (('Aalia', 'F'),        region sex  year   name  count      freq
# 598948     CA   F  2014  Aalia      7  0.000002
# 618326     CA   F  2019  Aalia      6  0.000002)
# (('Aaliyah', 'F'),         region sex  year     name  count      freq
# 6034503     WI   F  1998  Aaliyah     18  0.000005
# 2337545     LA   F  1998  Aaliyah     55  0.000017
# 3589731     NE   F  2016  Aaliyah     22  0.000007)
# (('Aalyah', 'F'),        region sex  year    name  count      freq
# 546322     CA   F  2001  Aalyah      6  0.000002)
# (('Aanya', 'F'),         region sex  year   name  count      freq
# 3736537     NJ   F  2007  Aanya     15  0.000004)
# (('Aaradhya', 'F'),         region sex  year      name  count      freq
# 3753667     NJ   F  2019  Aaradhya      5  0.000002)
# (('Aarav', 'M'),        region sex  year   name  count      freq
# 742134     CA   M  2006  Aarav     28  0.000008)
# (('Aaron', 'M'),         region sex  year   name  count      freq
# 1596321     IA   M  1959  Aaron     16  0.000004
# 4905964     RI   M  1996  Aaron     31  0.000010
# 5813804     VA   M  2005  Aaron    200  0.000060
# 5661765     UT   M  1995  Aaron    113  0.000035
# 143282      AL   M  1988  Aaron    152  0.000045)
# (('Aarush', 'M'),         region sex  year    name  count      freq
# 2895760     MI   M  2013  Aarush      5  0.000002)
# (('Abbey', 'F'),         region sex  year   name  count      freq
# 5736732     VA   F  2001  Abbey     15  0.000005
# 4053268     NY   F  1992  Abbey     17  0.000005
# 3397229     NC   F  2004  Abbey     27  0.000008)
# (('Abbie', 'F'),         region sex  year   name  count      freq
# 3213477     MS   F  2001  Abbie      7  0.000002
# 6143319     WV   F  1998  Abbie      5  0.000002
# 4728072     PA   F  1982  Abbie     12  0.000004
# 6025548     WI   F  1985  Abbie      5  0.000002)
# (('Abbigail', 'F'),         region sex  year      name  count      freq
# 5906475     WA   F  1998  Abbigail     12  0.000004)
# (('Abby', 'F'),         region sex  year  name  count      freq
# 4297877     OH   F  1968  Abby      7  0.000002
# 5922207     WA   F  2012  Abby     21  0.000007
# 1125179     FL   F  1990  Abby     37  0.000010)
# (('Abdallah', 'M'),         region sex  year      name  count      freq
# 4868847     PA   M  2019  Abdallah      5  0.000002)
# (('Abdiel', 'M'),         region sex  year    name  count      freq
# 6232803     PR   M  2009  Abdiel    107  0.000033)
# (('Abdullah', 'M'),         region sex  year      name  count      freq
# 4234593     NY   M  2011  Abdullah     47  0.000015
# 3502322     NC   M  2018  Abdullah      5  0.000002)
# (('Abe', 'M'),         region sex  year name  count      freq
# 1412649     GA   M  1959  Abe      5  0.000001
# 3756290     NJ   M  1915  Abe     23  0.000014)
# (('Abel', 'M'),         region sex  year  name  count      freq
# 882359      CO   M  2005  Abel     23  0.000007
# 6088722     WI   M  1994  Abel      6  0.000002
# 2651442     MD   M  2004  Abel     12  0.000004
# 3936388     NV   M  1994  Abel      5  0.000002
# 4168299     NY   M  1969  Abel     14  0.000004)
# (('Abelardo', 'M'),         region sex  year      name  count      freq
# 5437566     TX   M  1918  Abelardo     13  0.000006)
# (('Abhi', 'M'),        region sex  year  name  count      freq
# 769837     CA   M  2015  Abhi      6  0.000002)
# (('Abigail', 'F'),         region sex  year     name  count      freq
# 3861894     NM   F  2016  Abigail     48  0.000015
# 1639946     ID   F  1983  Abigail     11  0.000003
# 2579253     MD   F  1979  Abigail     15  0.000005
# 2331863     LA   F  1991  Abigail     41  0.000012
# 2608062     MD   F  2014  Abigail    230  0.000073
# 3968839     NY   F  1936  Abigail      8  0.000004)
# (('Abigale', 'F'),         region sex  year     name  count      freq
# 1352813     GA   F  2001  Abigale      8  0.000002
# 4763411     PA   F  2008  Abigale      8  0.000002)
# (('Abigayle', 'F'),         region sex  year      name  count      freq
# 1146890     FL   F  2002  Abigayle     15  0.000005
# 4965382     SC   F  2008  Abigayle      7  0.000002)
# (('Abraham', 'M'),         region sex  year     name  count      freq
# 2550703     MA   M  2020  Abraham     25  0.000009
# 5449384     TX   M  1930  Abraham     21  0.000010
# 2401757     LA   M  1987  Abraham      8  0.000002
# 3010071     MN   M  2007  Abraham     23  0.000007
# 1825869     IL   M  1927  Abraham      9  0.000004)
# (('Abram', 'M'),         region sex  year   name  count      freq
# 3550571     ND   M  2014  Abram      7  0.000002
# 4783765     PA   M  1910  Abram      5  0.000010
# 4842473     PA   M  1998  Abram      5  0.000002)
# (('Abubakar', 'M'),         region sex  year      name  count      freq
# 4452363     OH   M  2018  Abubakar      8  0.000003)
# (('Ada', 'F'),         region sex  year name  count      freq
# 4918307     SC   F  1926  Ada     50  0.000023
# 97274       AL   F  2014  Ada     12  0.000004
# 4306763     OH   F  1976  Ada     10  0.000004)
# (('Adalberto', 'M'),         region sex  year       name  count      freq
# 5483755     TX   M  1963  Adalberto     10  0.000003
# 1862738     IL   M  1979  Adalberto      6  0.000002)
# (('Adaline', 'F'),         region sex  year     name  count      freq
# 1183587     FL   F  2018  Adaline     74  0.000025)
# (('Adalyn', 'F'),         region sex  year    name  count      freq
# 2108059     KS   F  2014  Adalyn     34  0.000011)
# (('Adalynn', 'F'),         region sex  year     name  count      freq
# 3587788     NE   F  2012  Adalynn     15  0.000005)
# (('Adam', 'M'),         region sex  year  name  count      freq
# 5653135     UT   M  1974  Adam    145  0.000052
# 114602      AL   M  1932  Adam      5  0.000003
# 20466       AK   M  1979  Adam     36  0.000012
# 2364819     LA   M  1924  Adam     32  0.000014
# 5069504     SD   M  1970  Adam     11  0.000003)
# (('Adarian', 'M'),         region sex  year     name  count      freq
# 5552677     TX   M  2007  Adarian      6  0.000002)
# (('Addelyn', 'F'),         region sex  year     name  count      freq
# 4776322     PA   F  2016  Addelyn      9  0.000003)
# (('Addie', 'F'),         region sex  year   name  count      freq
# 1284588     GA   F  1913  Addie     63  0.000061
# 4353544     OH   F  2010  Addie      5  0.000002
# 3201382     MS   F  1979  Addie      5  0.000002
# 43088       AL   F  1935  Addie     46  0.000024)
# (('Addilynn', 'F'),        region sex  year      name  count      freq
# 219625     AR   F  2016  Addilynn     12  0.000004)
# (('Addison', 'F'),         region sex  year     name  count      freq
# 1379659     GA   F  2017  Addison    209  0.000069)
# (('Addison', 'M'),         region sex  year     name  count      freq
# 2417559     LA   M  2007  Addison      6  0.000002)
# (('Addisyn', 'F'),         region sex  year     name  count      freq
# 4767751     PA   F  2011  Addisyn     25  0.000008
# 101288      AL   F  2018  Addisyn      7  0.000002)
# (('Addyson', 'F'),         region sex  year     name  count      freq
# 1354774     GA   F  2002  Addyson      5  0.000002)
# (('Adel', 'M'),         region sex  year  name  count      freq
# 4247868     NY   M  2017  Adel      9  0.000003)
# (('Adela', 'F'),         region sex  year   name  count      freq
# 5265422     TX   F  1950  Adela     66  0.000020
# 1734515     IL   F  1971  Adela      5  0.000002)
# (('Adelaide', 'F'),         region sex  year      name  count      freq
# 2103409     KS   F  2007  Adelaide      7  0.000002)
# (('Adele', 'F'),         region sex  year   name  count      freq
# 3681224     NJ   F  1948  Adele     38  0.000012
# 3964714     NY   F  1931  Adele    140  0.000071)
# (('Adeline', 'F'),         region sex  year     name  count      freq
# 3510180     ND   F  1932  Adeline     10  0.000005
# 2342259     LA   F  2003  Adeline      7  0.000002
# 4457427     OK   F  1914  Adeline      5  0.000004)
# (('Adelyn', 'F'),         region sex  year    name  count      freq
# 5375956     TX   F  2005  Adelyn      7  0.000002)
# (('Adelynn', 'F'),         region sex  year     name  count      freq
# 5159420     TN   F  2020  Adelynn     24  0.000009)
# (('Aden', 'M'),         region sex  year  name  count      freq
# 3948375     NV   M  2018  Aden      8  0.000003)
# (('Adin', 'M'),         region sex  year  name  count      freq
# 2539857     MA   M  2006  Adin      5  0.000001)
# (('Adir', 'M'),         region sex  year  name  count      freq
# 4252518     NY   M  2019  Adir      5  0.000002)
# (('Adolfo', 'M'),         region sex  year    name  count      freq
# 5489809     TX   M  1969  Adolfo     43  0.000013)
# (('Adreanna', 'F'),         region sex  year      name  count      freq
# 1565847     IA   F  1998  Adreanna      5  0.000002)
# (('Adrian', 'F'),         region sex  year    name  count      freq
# 2783180     MI   F  1992  Adrian     11  0.000003
# 79157       AL   F  1992  Adrian     16  0.000005
# 2311296     LA   F  1966  Adrian      6  0.000002)
# (('Adrian', 'M'),         region sex  year    name  count      freq
# 2406586     LA   M  1994  Adrian     28  0.000008
# 2714559     ME   M  2010  Adrian      9  0.000003
# 4129297     NY   M  1920  Adrian     32  0.000015
# 2849016     MI   M  1961  Adrian     15  0.000004
# 21833       AK   M  1986  Adrian     10  0.000003)
# (('Adriana', 'F'),        region sex  year     name  count      freq
# 922570     CT   F  1985  Adriana      7  0.000002)
# (('Adriane', 'F'),         region sex  year     name  count      freq
# 4940431     SC   F  1969  Adriane      8  0.000002
# 1723390     IL   F  1962  Adriane      5  0.000001
# 461134      CA   F  1974  Adriane     10  0.000004)
# (('Adrianna', 'F'),         region sex  year      name  count      freq
# 3213251     MS   F  2001  Adrianna     19  0.000006
# 3858487     NM   F  2009  Adrianna     17  0.000005)
# (('Adrianne', 'F'),         region sex  year      name  count      freq
# 570263      CA   F  2007  Adrianne      7  0.000002
# 4053493     NY   F  1992  Adrianne     12  0.000003
# 1730199     IL   F  1968  Adrianne     10  0.000003
# 2813143     MI   F  2013  Adrianne      5  0.000002
# 5890532     WA   F  1979  Adrianne      6  0.000002)
# (('Adrien', 'M'),         region sex  year    name  count      freq
# 4895684     RI   M  1928  Adrien      5  0.000002
# 2899038     MI   M  2016  Adrien     10  0.000003)
# (('Adrienne', 'F'),         region sex  year      name  count      freq
# 2668148     ME   F  1920  Adrienne      6  0.000003)
# (('Adrina', 'F'),         region sex  year    name  count      freq
# 5383712     TX   F  2007  Adrina      5  0.000001)
# (('Advait', 'M'),        region sex  year    name  count      freq
# 766534     CA   M  2014  Advait      8  0.000003)
# (('Afton', 'F'),         region sex  year   name  count      freq
# 4494945     OK   F  1985  Afton      6  0.000002)
# (('Agatha', 'F'),         region sex  year    name  count      freq
# 4680250     PA   F  1930  Agatha     13  0.000006)
# (('Agnes', 'F'),         region sex  year   name  count      freq
# 3697312     NJ   F  1970  Agnes      8  0.000002
# 5100324     TN   F  1949  Agnes     17  0.000005
# 2281356     LA   F  1918  Agnes    134  0.000067
# 5096443     TN   F  1942  Agnes     35  0.000014)
# (('Agustine', 'M'),         region sex  year      name  count      freq
# 5515609     TX   M  1988  Agustine      5  0.000001)
# (('Ahmad', 'M'),         region sex  year   name  count      freq
# 4428893     OH   M  2000  Ahmad     16  0.000005)
# (('Ahmari', 'M'),         region sex  year    name  count      freq
# 4239795     NY   M  2013  Ahmari      7  0.000002)
# (('Ahmed', 'M'),         region sex  year   name  count      freq
# 3780733     NJ   M  1974  Ahmed     11  0.000004
# 4176626     NY   M  1976  Ahmed     17  0.000006)
# (('Aida', 'F'),         region sex  year  name  count      freq
# 5342439     TX   F  1994  Aida     21  0.000006)
# (('Aidan', 'F'),         region sex  year   name  count      freq
# 4337259     OH   F  2000  Aidan      7  0.000002)
# (('Aidan', 'M'),         region sex  year   name  count      freq
# 4854209     PA   M  2009  Aidan    272  0.000083)
# (('Aiden', 'M'),         region sex  year   name  count      freq
# 2877701     MI   M  1998  Aiden     12  0.000004)
# (('Aila', 'F'),         region sex  year  name  count      freq
# 5922943     WA   F  2012  Aila      5  0.000002)
# (('Aileen', 'F'),         region sex  year    name  count      freq
# 394206      CA   F  1919  Aileen     27  0.000014
# 3824560     NM   F  1918  Aileen      5  0.000002)
# (('Aimee', 'F'),         region sex  year   name  count      freq
# 2931697     MN   F  1971  Aimee     31  0.000010
# 1485367     HI   F  1970  Aimee      9  0.000003
# 3399134     NC   F  2005  Aimee     10  0.000003
# 201429      AR   F  1983  Aimee      9  0.000003
# 2083412     KS   F  1968  Aimee      7  0.000002
# 5744892     VA   F  2007  Aimee      5  0.000001
# 4344765     OH   F  2005  Aimee      8  0.000002)
# (('Ainsley', 'F'),         region sex  year     name  count      freq
# 1806466     IL   F  2015  Ainsley     37  0.000012
# 1977776     IN   F  2004  Ainsley     23  0.000007
# 3747781     NJ   F  2015  Ainsley     10  0.000003
# 328764      AZ   F  2013  Ainsley     22  0.000007)
# (('Aisha', 'F'),         region sex  year   name  count      freq
# 1967428     IN   F  1993  Aisha      7  0.000002
# 1753473     IL   F  1985  Aisha     27  0.000008)
# (('Aislynn', 'F'),         region sex  year     name  count      freq
# 3423757     NC   F  2020  Aislynn      5  0.000002)
# (('Aiza', 'F'),         region sex  year  name  count      freq
# 4109731     NY   F  2015  Aiza     19  0.000006)
# (('Aj', 'M'),        region sex  year name  count      freq
# 772061     CA   M  2016   Aj     11  0.000004)
# (('Aja', 'F'),         region sex  year name  count      freq
# 5908931     WA   F  2000  Aja      5  0.000001)
# (('Ajah', 'F'),         region sex  year  name  count      freq
# 5734843     VA   F  1999  Ajah      7  0.000002)
# (('Ajanae', 'F'),         region sex  year    name  count      freq
# 2795494     MI   F  2001  Ajanae      6  0.000002)
# (('Ajay', 'M'),         region sex  year  name  count      freq
# 4189707     NY   M  1986  Ajay     10  0.000003)
# (('Ajla', 'F'),         region sex  year  name  count      freq
# 1568489     IA   F  2003  Ajla      7  0.000002)
# (('Akeem', 'M'),         region sex  year   name  count      freq
# 4831867     PA   M  1987  Akeem     26  0.000008)
# (('Akira', 'F'),        region sex  year   name  count      freq
# 524127     CA   F  1995  Akira      8  0.000002)
# (('Al', 'M'),         region sex  year name  count      freq
# 3252612     MS   M  1969   Al      6  0.000002)
# (('Alain', 'M'),         region sex  year   name  count      freq
# 4183036     NY   M  1981  Alain     14  0.000004)
# (('Alaina', 'F'),         region sex  year    name  count      freq
# 6147501     WV   F  2010  Alaina     17  0.000005
# 4740031     PA   F  1992  Alaina     40  0.000012
# 1653540     ID   F  2019  Alaina      5  0.000002
# 3726327     NJ   F  1999  Alaina     12  0.000004
# 2604158     MD   F  2010  Alaina     24  0.000008)
# (('Alan', 'M'),         region sex  year  name  count      freq
# 1058225     DE   M  1958  Alan     21  0.000005
# 4385021     OH   M  1941  Alan    153  0.000067
# 859969      CO   M  1961  Alan    105  0.000027
# ...        ...  ..   ...   ...    ...       ...
# 4626504     OR   M  1915  Alan      6  0.000004
# 17782       AK   M  1961  Alan     11  0.000003
# 136154      AL   M  1974  Alan     33  0.000012
# [8 rows x 6 columns])
# (('Alana', 'F'),         region sex  year   name  count      freq
# 5608995     UT   F  1980  Alana      8  0.000003
# 4884841     RI   F  1983  Alana      5  0.000002
# 4767488     PA   F  2011  Alana     73  0.000023
# 529369      CA   F  1997  Alana    124  0.000039)
# (('Alanna', 'F'),         region sex  year    name  count      freq
# 5352671     TX   F  1998  Alanna     28  0.000009
# 4615666     OR   F  2007  Alanna      5  0.000001
# 1337027     GA   F  1988  Alanna      6  0.000002
# 612341      CA   F  2018  Alanna     67  0.000023
# 940114      CT   F  2016  Alanna      7  0.000002
# 1742471     IL   F  1977  Alanna      7  0.000002
# 3926347     NV   F  2020  Alanna      6  0.000002)
# (('Alayah', 'F'),         region sex  year    name  count      freq
# 6043567     WI   F  2008  Alayah      6  0.000002)
# (('Alayna', 'F'),         region sex  year    name  count      freq
# 6146436     WV   F  2007  Alayna      8  0.000002)
# (('Albert', 'M'),         region sex  year    name  count      freq
# 240052      AR   M  1953  Albert     71  0.000019
# 223946      AR   M  1915  Albert    112  0.000066
# 246350      AR   M  1969  Albert     27  0.000008
# ...        ...  ..   ...     ...    ...       ...
# 2268677     KY   M  2007  Albert      5  0.000001
# 5847837     VT   M  1919  Albert     32  0.000016
# 978879      CT   M  2019  Albert      7  0.000002
#
# [8 rows x 6 columns])
# (('Alberta', 'F'),         region sex  year     name  count      freq
# 5094027     TN   F  1937  Alberta     17  0.000009
# 3986255     NY   F  1954  Alberta     30  0.000008
# 4713632     PA   F  1969  Alberta     12  0.000004
# 1301551     GA   F  1943  Alberta     34  0.000013
# 3175356     MS   F  1933  Alberta     57  0.000031)
# (('Albin', 'M'),         region sex  year   name  count      freq
# 2973564     MN   M  1921  Albin      9  0.000004
# 1822344     IL   M  1921  Albin     15  0.000007)
# (('Aldo', 'M'),         region sex  year  name  count      freq
# 6099839     WI   M  2010  Aldo     10  0.000003)
# (('Aleah', 'F'),         region sex  year   name  count      freq
# 5760750     VA   F  2019  Aleah     13  0.000004)
# (('Alease', 'F'),         region sex  year    name  count      freq
# 3350756     NC   F  1951  Alease      5  0.000001)
# (('Alec', 'M'),         region sex  year  name  count      freq
# 5659641     UT   M  1990  Alec     16  0.000004
# 5202224     TN   M  1996  Alec     39  0.000012
# 3659911     NH   M  1994  Alec     23  0.000007
# 4650083     OR   M  1995  Alec     45  0.000014)
# (('Alecia', 'F'),         region sex  year    name  count      freq
# 5305644     TX   F  1977  Alecia     16  0.000006
# 5309164     TX   F  1979  Alecia     26  0.000009)
# (('Aleem', 'M'),         region sex  year   name  count      freq
# 4857934     PA   M  2011  Aleem      5  0.000002)
# (('Aleena', 'F'),         region sex  year    name  count      freq
# 4758516     PA   F  2005  Aleena     10  0.000003
# 588465      CA   F  2012  Aleena    131  0.000042)
# (('Aleesha', 'F'),         region sex  year     name  count      freq
# 1136186     FL   F  1996  Aleesha      6  0.000002)
# (('Aleia', 'F'),         region sex  year   name  count      freq
# 5314307     TX   F  1981  Aleia      5  0.000002)
# (('Aleigha', 'F'),         region sex  year     name  count      freq
# 1368191     GA   F  2010  Aleigha     13  0.000004)
# (('Alejandra', 'F'),         region sex  year       name  count      freq
# 5285069     TX   F  1964  Alejandra     18  0.000005
# 2948669     MN   F  1998  Alejandra     13  0.000004
# 1567886     IA   F  2002  Alejandra      8  0.000002)
# (('Alejandro', 'M'),         region sex  year       name  count      freq
# 377719      AZ   M  2008  Alejandro    208  0.000062
# 4450514     OH   M  2017  Alejandro     23  0.000008
# 2652043     MD   M  2005  Alejandro     29  0.000009
# 4823831     PA   M  1976  Alejandro      8  0.000003)
# (('Alek', 'M'),         region sex  year  name  count      freq
# 1243459     FL   M  1998  Alek      7  0.000002)
# (('Aleksandra', 'F'),         region sex  year        name  count      freq
# 4091553     NY   F  2008  Aleksandra     22  0.000007)
# (('Alena', 'F'),         region sex  year   name  count      freq
# 1357476     GA   F  2004  Alena     11  0.000003)
# (('Alesha', 'F'),         region sex  year    name  count      freq
# 5891232     WA   F  1980  Alesha      7  0.000002)
# (('Alessandra', 'F'),         region sex  year        name  count      freq
# 4025389     NY   F  1978  Alessandra      8  0.000003
# 4621109     OR   F  2014  Alessandra      6  0.000002)
# (('Alex', 'F'),         region sex  year  name  count      freq
# 4766701     PA   F  2010  Alex      8  0.000003)
# (('Alex', 'M'),         region sex  year  name  count      freq
# 3119303     MO   M  1952  Alex      6  0.000002
# 1512471     HI   M  1973  Alex      5  0.000002
# 684334      CA   M  1982  Alex    391  0.000122
# ...        ...  ..   ...   ...    ...       ...
# 2843035     MI   M  1952  Alex     15  0.000004
# 2854037     MI   M  1969  Alex     48  0.000015
# 3894364     NM   M  2008  Alex     33  0.000010
#
# [8 rows x 6 columns])
# (('Alexa', 'F'),         region sex  year   name  count      freq
# 218724      AR   F  2015  Alexa     46  0.000015
# 5897041     WA   F  1988  Alexa     27  0.000008
# 2966105     MN   F  2017  Alexa     31  0.000010
# 2339323     LA   F  2000  Alexa     28  0.000008)
# (('Alexander', 'M'),         region sex  year       name  count      freq
# 1866982     IL   M  1984  Alexander    361  0.000114
# 950204      CT   M  1947  Alexander     19  0.000006
# 4652701     OR   M  2000  Alexander    204  0.000061
# 2631366     MD   M  1966  Alexander     34  0.000010
# 5854912     VT   M  1976  Alexander      5  0.000002
# 1911216     IL   M  2017  Alexander    584  0.000193
# 28706       AK   M  2018  Alexander     18  0.000006)
# (('Alexandra', 'F'),         region sex  year       name  count      freq
# 919586      CT   F  1979  Alexandra     39  0.000013
# 4369326     OH   F  2020  Alexandra     31  0.000011
# 4696692     PA   F  1952  Alexandra     13  0.000004
# 6023904     WI   F  1983  Alexandra     23  0.000007
# 547265      CA   F  2002  Alexandra   1000  0.000305
# 4605278     OR   F  1993  Alexandra     97  0.000029)
# (('Alexandre', 'M'),         region sex  year       name  count      freq
# 3804843     NJ   M  2004  Alexandre      7  0.000002)
# (('Alexandrea', 'F'),         region sex  year        name  count      freq
# 3578959     NE   F  1991  Alexandrea      7  0.000002
# 4739059     PA   F  1991  Alexandrea     12  0.000003)
# (('Alexandria', 'F'),         region sex  year        name  count      freq
# 4621651     OR   F  2015  Alexandria     12  0.000004
# 5729435     VA   F  1994  Alexandria     59  0.000018
# 1994620     IN   F  2018  Alexandria     23  0.000008)
# (('Alexandro', 'M'),         region sex  year       name  count      freq
# 5539716     TX   M  2002  Alexandro     52  0.000016
# 5510367     TX   M  1985  Alexandro     20  0.000006)
# (('Alexia', 'F'),         region sex  year    name  count      freq
# 3582230     NE   F  2000  Alexia     12  0.000004
# 507670      CA   F  1991  Alexia     52  0.000015
# 5346858     TX   F  1996  Alexia    130  0.000040
# 2499250     MA   F  2020  Alexia      6  0.000002)
# (('Alexis', 'F'),         region sex  year    name  count      freq
# 1569287     IA   F  2005  Alexis    137  0.000041
# 931404      CT   F  2002  Alexis    130  0.000040
# 930842      CT   F  2001  Alexis    117  0.000036)
# (('Alexus', 'F'),         region sex  year    name  count      freq
# 330842      AZ   F  2014  Alexus      5  0.000002
# 4100859     NY   F  2011  Alexus      5  0.000002
# 211055      AR   F  2003  Alexus     17  0.000005)
# (('Alexxus', 'F'),         region sex  year     name  count      freq
# 5357230     TX   F  1999  Alexxus      5  0.000002)
# (('Alexzander', 'M'),         region sex  year        name  count      freq
# 3482251     NC   M  2002  Alexzander      9  0.000003)
# (('Alfonso', 'M'),         region sex  year     name  count      freq
# 1231748     FL   M  1989  Alfonso     22  0.000006
# 5467783     TX   M  1949  Alfonso     89  0.000027
# 1821291     IL   M  1919  Alfonso     10  0.000005)
# (('Alford', 'M'),         region sex  year    name  count      freq
# 2226950     KY   M  1919  Alford      5  0.000003)
# (('Alfred', 'M'),         region sex  year    name  count      freq
# 1505222     HI   M  1945  Alfred     24  0.000010
# 1502141     HI   M  1924  Alfred     34  0.000015
# 1517503     HI   M  1990  Alfred      6  0.000002
# ...        ...  ..   ...     ...    ...       ...
# 4784979     PA   M  1914  Alfred    263  0.000203
# 1502988     HI   M  1929  Alfred     32  0.000016
# 362741      AZ   M  1988  Alfred     14  0.000004
#
# [9 rows x 6 columns])
# (('Ali', 'F'),         region sex  year name  count      freq
# 2792592     MI   F  1999  Ali      7  0.000002)
# (('Ali', 'M'),         region sex  year name  count      freq
# 4404713     OH   M  1971  Ali      7  0.000002)
# (('Aliana', 'F'),         region sex  year    name  count      freq
# 2614237     MD   F  2019  Aliana      5  0.000002)
# (('Alianna', 'F'),         region sex  year     name  count      freq
# 1986663     IN   F  2011  Alianna      6  0.000002
# 1184253     FL   F  2018  Alianna     16  0.000005)
# (('Alice', 'F'),         region sex  year   name  count      freq
# 1339751     GA   F  1991  Alice     23  0.000007
# 2673559     ME   F  1944  Alice     34  0.000013
# 4463461     OK   F  1926  Alice    169  0.000079
# 3631994     NH   F  1951  Alice     17  0.000005
# 5248263     TX   F  1934  Alice    359  0.000186
# 5246295     TX   F  1932  Alice    393  0.000200)
# (('Alicia', 'F'),         region sex  year    name  count      freq
# 4484490     OK   F  1967  Alicia     26  0.000008
# 3828466     NM   F  1934  Alicia      8  0.000004
# 1757487     IL   F  1988  Alicia    291  0.000087
# 4698325     PA   F  1954  Alicia     38  0.000010
# 6198949     WY   F  1999  Alicia      8  0.000002)
# (('Alijah', 'M'),         region sex  year    name  count      freq
# 5209589     TN   M  2005  Alijah      9  0.000003
# 4425143     OH   M  1996  Alijah      6  0.000002
# 159098      AL   M  2011  Alijah     12  0.000004)
# (('Alina', 'F'),         region sex  year   name  count      freq
# 2489973     MA   F  2011  Alina     25  0.000008
# 1157347     FL   F  2007  Alina    111  0.000032
# 2462918     MA   F  1978  Alina      7  0.000002)
# (('Aline', 'F'),         region sex  year   name  count      freq
# 2552556     MD   F  1915  Aline      5  0.000003)
# (('Alisa', 'F'),         region sex  year   name  count      freq
# 2310153     LA   F  1965  Alisa     31  0.000009
# 1551024     IA   F  1967  Alisa      9  0.000003
# 1321512     GA   F  1971  Alisa     33  0.000010
# 64579       AL   F  1970  Alisa     14  0.000004)
# (('Alisha', 'F'),         region sex  year    name  count      freq
# 5316909     TX   F  1983  Alisha    121  0.000038
# 69663       AL   F  1978  Alisha     39  0.000014
# 5607209     UT   F  1977  Alisha     37  0.000013
# 3906117     NV   F  1977  Alisha     12  0.000004)
# (('Alison', 'F'),         region sex  year    name  count      freq
# 2201119     KY   F  1991  Alison     24  0.000007
# 2443262     MA   F  1944  Alison      7  0.000003
# 992748      DC   F  1966  Alison      9  0.000003
# 296217      AZ   F  1982  Alison     26  0.000008)
# (('Alissa', 'F'),         region sex  year    name  count      freq
# 1740497     IL   F  1976  Alissa     26  0.000009
# 5893342     WA   F  1983  Alissa     13  0.000004
# 4941641     SC   F  1971  Alissa      6  0.000002)
# (('Alivia', 'F'),         region sex  year    name  count      freq
# 4746933     PA   F  1997  Alivia     18  0.000006)
# (('Alix', 'M'),         region sex  year  name  count      freq
# 1239320     FL   M  1995  Alix      9  0.000003)
# (('Aliya', 'F'),         region sex  year   name  count      freq
# 4767847     PA   F  2011  Aliya     20  0.000006
# 1162609     FL   F  2009  Aliya     27  0.000008
# 4076537     NY   F  2002  Aliya     22  0.000007)
# (('Aliyah', 'F'),         region sex  year    name  count      freq
# 5930882     WA   F  2019  Aliyah     44  0.000015
# 6150877     WV   F  2018  Aliyah      6  0.000002
# 3394313     NC   F  2002  Aliyah     53  0.000016)
# (('Aliza', 'F'),        region sex  year   name  count      freq
# 597338     CA   F  2014  Aliza     28  0.000009)
# (('Allan', 'M'),         region sex  year   name  count      freq
# 3608310     NE   M  1970  Allan      5  0.000001
# 4182743     NY   M  1981  Allan     49  0.000016
# 1821663     IL   M  1920  Allan     42  0.000020
# 2250874     KY   M  1969  Allan      6  0.000002)
# (('Allegra', 'F'),         region sex  year     name  count      freq
# 4109950     NY   F  2015  Allegra     14  0.000004)
# (('Allen', 'M'),         region sex  year   name  count      freq
# 4181350     NY   M  1980  Allen    101  0.000032
# 3263053     MS   M  1992  Allen     25  0.000007
# 5790758     VA   M  1971  Allen     76  0.000024
# ...        ...  ..   ...    ...    ...       ...
# 5519159     TX   M  1991  Allen    140  0.000040
# 4794690     PA   M  1930  Allen    162  0.000078
# 6171698     WV   M  1968  Allen     35  0.000011
#
# [11 rows x 6 columns])
# (('Allena', 'F'),         region sex  year    name  count      freq
# 3412445     NC   F  2013  Allena      5  0.000002)
# (('Allene', 'F'),         region sex  year    name  count      freq
# 5259016     TX   F  1944  Allene     10  0.000004
# 5684100     VA   F  1920  Allene      8  0.000004
# 5690534     VA   F  1934  Allene      8  0.000004)
# (('Allie', 'F'),         region sex  year   name  count      freq
# 1802711     IL   F  2013  Allie     38  0.000012
# 1300593     GA   F  1941  Allie      9  0.000004)
# (('Allison', 'F'),         region sex  year     name  count      freq
# 4969218     SC   F  2013  Allison     82  0.000026
# 2309250     LA   F  1964  Allison     65  0.000018
# 6050809     WI   F  2016  Allison     45  0.000014
# 3098004     MO   F  2018  Allison     65  0.000022
# 5117199     TN   F  1976  Allison    106  0.000038
# 4883856     RI   F  1979  Allison     24  0.000008)
# (('Allison', 'M'),         region sex  year     name  count      freq
# 4803821     PA   M  1946  Allison      8  0.000003)
# (('Ally', 'F'),         region sex  year  name  count      freq
# 2494275     MA   F  2015  Ally      7  0.000002
# 3405484     NC   F  2009  Ally     10  0.000003
# 1774485     IL   F  1998  Ally     24  0.000007)
# (('Allyn', 'M'),         region sex  year   name  count      freq
# 1594628     IA   M  1954  Allyn      5  0.000001)
# (('Allyson', 'F'),         region sex  year     name  count      freq
# 2205360     KY   F  1998  Allyson     28  0.000009
# 3373176     NC   F  1981  Allyson     15  0.000005)
# (('Allyssa', 'F'),         region sex  year     name  count      freq
# 4514631     OK   F  2012  Allyssa      5  0.000002)
# (('Alma', 'F'),         region sex  year  name  count      freq
# 2599354     MD   F  2005  Alma      8  0.000002
# 3667505     NJ   F  1915  Alma     60  0.000036
# 4766927     PA   F  2010  Alma      6  0.000002
# 4509175     OK   F  2006  Alma      6  0.000002
# 174864      AR   F  1927  Alma    108  0.000050)
# (('Alnisa', 'F'),         region sex  year    name  count      freq
# 3710159     NJ   F  1984  Alnisa      7  0.000002)
# (('Alonso', 'M'),         region sex  year    name  count      freq
# 5516289     TX   M  1989  Alonso     33  0.000009)
# (('Alonzo', 'M'),         region sex  year    name  count      freq
# 2021567     IN   M  1968  Alonzo      7  0.000002
# 236666      AR   M  1944  Alonzo      7  0.000003
# 2382447     LA   M  1958  Alonzo     18  0.000005)
# (('Alpha', 'F'),         region sex  year   name  count      freq
# 5263843     TX   F  1948  Alpha      5  0.000002)
# (('Alphonse', 'M'),         region sex  year      name  count      freq
# 3241379     MS   M  1945  Alphonse      5  0.000002)
# (('Alta', 'F'),         region sex  year  name  count      freq
# 2177263     KY   F  1949  Alta     10  0.000003
# 2160953     KY   F  1919  Alta     38  0.000019)
# (('Altha', 'F'),         region sex  year   name  count      freq
# 4467620     OK   F  1933  Altha      5  0.000003)
# (('Althea', 'F'),         region sex  year    name  count      freq
# 446535      CA   F  1967  Althea     13  0.000004
# 2668302     ME   F  1921  Althea     16  0.000007
# 4680831     PA   F  1931  Althea     24  0.000012)
# (('Alton', 'M'),         region sex  year   name  count      freq
# 3782083     NJ   M  1976  Alton      7  0.000003
# 3242529     MS   M  1948  Alton     29  0.000009
# 3432337     NC   M  1926  Alton     73  0.000034
# 2415924     LA   M  2005  Alton      5  0.000001
# 6077555     WI   M  1971  Alton      6  0.000002
# 4991829     SC   M  1949  Alton     20  0.000006)
# (('Alva', 'F'),         region sex  year  name  count     freq
# 5239346     TX   F  1925  Alva     22  0.00001)
# (('Alvera', 'F'),         region sex  year    name  count      freq
# 4670292     PA   F  1916  Alvera      5  0.000003)
# (('Alvin', 'M'),         region sex  year   name  count      freq
# 884411      CO   M  2007  Alvin      5  0.000001
# 1581761     IA   M  1917  Alvin     61  0.000033
# 1230495     FL   M  1988  Alvin     40  0.000012
# 2982341     MN   M  1946  Alvin     22  0.000007
# 5069937     SD   M  1972  Alvin      6  0.000002
# 4165827     NY   M  1967  Alvin     73  0.000023)
# (('Alvina', 'F'),         region sex  year    name  count      freq
# 5248991     TX   F  1934  Alvina      7  0.000004)
# (('Alyanna', 'F'),         region sex  year     name  count      freq
# 5415105     TX   F  2016  Alyanna     21  0.000007)
# (('Alyce', 'F'),         region sex  year   name  count      freq
# 4717283     PA   F  1972  Alyce      5  0.000002)
# (('Alyse', 'F'),       region sex  year   name  count      freq
# 87826     AL   F  2003  Alyse      5  0.000002)
# (('Alysha', 'F'),         region sex  year    name  count      freq
# 1960109     IN   F  1984  Alysha      7  0.000002)
# (('Alyshia', 'F'),         region sex  year     name  count      freq
# 2781036     MI   F  1990  Alyshia      5  0.000001)
# (('Alyson', 'F'),         region sex  year    name  count      freq
# 4019002     NY   F  1975  Alyson     38  0.000014)
# (('Alyssa', 'F'),         region sex  year    name  count      freq
# 1967736     IN   F  1994  Alyssa    260  0.000079
# 1003129     DC   F  1998  Alyssa     12  0.000004
# 2795863     MI   F  2002  Alyssa    456  0.000139
# 4502538     OK   F  1998  Alyssa    151  0.000046
# 6199236     WY   F  2002  Alyssa     20  0.000006)
# (('Alyvia', 'F'),         region sex  year    name  count      freq
# 1367203     GA   F  2009  Alyvia      5  0.000002)
# (('Alyza', 'F'),        region sex  year   name  count      freq
# 538555     CA   F  1999  Alyza      7  0.000002)
# (('Amahia', 'F'),         region sex  year    name  count      freq
# 4118606     NY   F  2018  Amahia      5  0.000002)
# (('Amalia', 'F'),        region sex  year    name  count      freq
# 572699     CA   F  2008  Amalia     32  0.000009)
# (('Amanda', 'F'),         region sex  year    name  count      freq
# 3852428     NM   F  1997  Amanda     79  0.000025
# 1945399     IN   F  1965  Amanda     51  0.000015
# 5887415     WA   F  1975  Amanda    179  0.000065
# 5098154     TN   F  1945  Amanda     10  0.000004)
# (('Amani', 'F'),        region sex  year   name  count      freq
# 938830     CT   F  2014  Amani     11  0.000003)
# (('Amarah', 'F'),        region sex  year    name  count      freq
# 553543     CA   F  2003  Amarah      8  0.000002)
# (('Amari', 'F'),         region sex  year   name  count      freq
# 3220988     MS   F  2013  Amari     22  0.000007)
# (('Amariah', 'F'),        region sex  year     name  count      freq
# 549640     CA   F  2002  Amariah      8  0.000002
# 565407     CA   F  2006  Amariah     10  0.000003)
# (('Amarion', 'M'),         region sex  year     name  count      freq
# 2416564     LA   M  2006  Amarion      8  0.000002)
# (('Amaya', 'F'),         region sex  year   name  count      freq
# 4620781     OR   F  2014  Amaya     14  0.000004)
# (('Amber', 'F'),         region sex  year   name  count      freq
# 4501198     OK   F  1996  Amber    111  0.000034
# 1953437     IN   F  1976  Amber    255  0.000093
# 5261330     TX   F  1946  Amber      7  0.000002
# 3079803     MO   F  2001  Amber    146  0.000044
# 6198856     WY   F  1998  Amber      6  0.000002
# 4355878     OH   F  2012  Amber     22  0.000007
# 5703850     VA   F  1959  Amber      8  0.000002)
# (('Amberly', 'F'),         region sex  year     name  count      freq
# 4120073     NY   F  2019  Amberly     12  0.000004)
# (('Ambika', 'F'),         region sex  year    name  count      freq
# 4068020     NY   F  1998  Ambika      6  0.000002)
# (('Ambrosio', 'M'),         region sex  year      name  count      freq
# 5503745     TX   M  1980  Ambrosio      7  0.000002)
# (('Ameer', 'M'),         region sex  year   name  count      freq
# 4453458     OH   M  2019  Ameer     15  0.000005
# 1458067     GA   M  2011  Ameer      9  0.000003)
# (('Ameerah', 'F'),         region sex  year     name  count      freq
# 4110498     NY   F  2015  Ameerah      8  0.000003)
# (('Amelia', 'F'),         region sex  year    name  count      freq
# 4921066     SC   F  1932  Amelia     11  0.000006
# 32876       AL   F  1917  Amelia      8  0.000004
# 2322392     LA   F  1980  Amelia     15  0.000005
# 6027848     WI   F  1989  Amelia     20  0.000006)
# (('Amelie', 'F'),        region sex  year    name  count      freq
# 838660     CO   F  2013  Amelie     11  0.000004)
# (('Amethyst', 'F'),         region sex  year      name  count      freq
# 5393692     TX   F  2010  Amethyst     10  0.000003)
# (('Amiah', 'F'),         region sex  year   name  count      freq
# 1174658     FL   F  2014  Amiah     16  0.000005)
# (('Amie', 'F'),         region sex  year  name  count      freq
# 2681446     ME   F  1972  Amie      5  0.000002
# 3170397     MS   F  1923  Amie      5  0.000002)
# (('Amiee', 'F'),         region sex  year   name  count      freq
# 5343803     TX   F  1994  Amiee      5  0.000002)
# (('Amilia', 'F'),         region sex  year    name  count      freq
# 4363427     OH   F  2016  Amilia      6  0.000002)
# (('Amina', 'F'),         region sex  year   name  count      freq
# 6051939     WI   F  2017  Amina     21  0.000007)
# (('Aminah', 'F'),         region sex  year    name  count      freq
# 6053315     WI   F  2018  Aminah      7  0.000002)
# (('Amir', 'M'),         region sex  year  name  count      freq
# 662509      CA   M  1966  Amir      5  0.000002
# 4658083     OR   M  2008  Amir      6  0.000002)
# (('Amira', 'F'),         region sex  year   name  count      freq
# 1355657     GA   F  2003  Amira     14  0.000004
# 3747571     NJ   F  2015  Amira     15  0.000005)
# (('Amity', 'F'),         region sex  year   name  count      freq
# 1956383     IN   F  1979  Amity      5  0.000002)
# (('Amiya', 'F'),         region sex  year   name  count      freq
# 5918640     WA   F  2009  Amiya     12  0.000004
# 6040792     WI   F  2005  Amiya      5  0.000001)
# (('Amoni', 'F'),         region sex  year   name  count      freq
# 5751683     VA   F  2012  Amoni      5  0.000002)
# (('Amora', 'F'),         region sex  year   name  count      freq
# 4095239     NY   F  2009  Amora      7  0.000002)
# (('Amos', 'M'),         region sex  year  name  count      freq
# 666107      CA   M  1969  Amos      6  0.000002
# 2628562     MD   M  1959  Amos      9  0.000002
# 4813316     PA   M  1961  Amos     20  0.000005
# 2264460     KY   M  2000  Amos      5  0.000001)
# (('Amy', 'F'),         region sex  year name  count      freq
# 3571040     NE   F  1969  Amy    261  0.000080
# 6226246     PR   F  2017  Amy     14  0.000005
# 3030318     MO   F  1926  Amy     12  0.000006
# ...        ...  ..   ...  ...    ...       ...
# 3023667     MO   F  1914  Amy     13  0.000010
# 927654      CT   F  1995  Amy     59  0.000018
# 3748548     NJ   F  2016  Amy     67  0.000021
#
# [8 rows x 6 columns])
# (('Amyah', 'F'),        region sex  year   name  count      freq
# 614698     CA   F  2018  Amyah      6  0.000002)
# (('An', 'M'),        region sex  year name  count      freq
# 709770     CA   M  1993   An      8  0.000002)
# (('Ana', 'F'),         region sex  year name  count      freq
# 933408      CT   F  2005  Ana     12  0.000004
# 449612      CA   F  1969  Ana    241  0.000074
# 1099883     FL   F  1969  Ana     41  0.000013)
# (('Ana', 'M'),        region sex  year name  count      freq
# 692953     CA   M  1986  Ana      9  0.000003)
# (('Anabel', 'F'),         region sex  year    name  count      freq
# 3408858     NC   F  2011  Anabel      8  0.000003
# 1762670     IL   F  1991  Anabel     23  0.000007)
# (('Anabelle', 'F'),         region sex  year      name  count      freq
# 2806556     MI   F  2009  Anabelle     16  0.000005)
# (('Analisa', 'F'),        region sex  year     name  count      freq
# 519401     CA   F  1994  Analisa     22  0.000007)
# (('Anastacia', 'F'),         region sex  year       name  count      freq
# 5250032     TX   F  1935  Anastacia      6  0.000003)
# (('Anastasia', 'F'),         region sex  year       name  count      freq
# 5622566     UT   F  2003  Anastasia     16  0.000005
# 1562215     IA   F  1991  Anastasia      7  0.000002)
# (('Anay', 'F'),        region sex  year  name  count      freq
# 554116     CA   F  2003  Anay      6  0.000002)
# (('Anaya', 'F'),         region sex  year   name  count      freq
# 2352710     LA   F  2014  Anaya      8  0.000003
# 619425      CA   F  2020  Anaya    122  0.000044
# 2110041     KS   F  2016  Anaya      5  0.000002
# 2611461     MD   F  2017  Anaya     24  0.000008
# 1790943     IL   F  2007  Anaya     42  0.000012)
# (('Anayeli', 'F'),        region sex  year     name  count      freq
# 317530     AZ   F  2004  Anayeli      5  0.000002)
# (('Andera', 'F'),        region sex  year    name  count      freq
# 513965     CA   F  1992  Andera      5  0.000001)
# (('Anders', 'M'),         region sex  year    name  count      freq
# 4868704     PA   M  2019  Anders      6  0.000002
# 2533013     MA   M  1996  Anders      5  0.000002)
# (('Andersen', 'M'),        region sex  year      name  count      freq
# 784194     CA   M  2020  Andersen      6  0.000002)
# (('Andi', 'F'),         region sex  year  name  count      freq
# 5632163     UT   F  2014  Andi     10  0.000003)
# (('Andie', 'F'),         region sex  year   name  count      freq
# 2803919     MI   F  2007  Andie      9  0.000003)
# (('Andrae', 'M'),         region sex  year    name  count      freq
# 5005217     SC   M  1978  Andrae      8  0.000003)
# (('Andre', 'M'),         region sex  year   name  count      freq
# 5582491     TX   M  2019  Andre    171  0.000059
# 2638682     MD   M  1984  Andre     63  0.000020)
# (('Andrea', 'F'),         region sex  year    name  count      freq
# 3072829     MO   F  1993  Andrea    169  0.000050
# 2082719     KS   F  1967  Andrea     51  0.000016
# 1044966     DE   F  1975  Andrea     27  0.000010
# ...        ...  ..   ...     ...    ...       ...
# 3569023     NE   F  1963  Andrea     27  0.000007
# 4878206     RI   F  1954  Andrea     18  0.000005
# 5868657     WA   F  1939  Andrea     12  0.000006
#
# [10 rows x 6 columns])
# (('Andrei', 'M'),         region sex  year    name  count      freq
# 1909359     IL   M  2015  Andrei      6  0.000002)
# (('Andres', 'M'),         region sex  year    name  count      freq
# 4563607     OK   M  2005  Andres     18  0.000005
# 166249      AL   M  2020  Andres     18  0.000006
# 2885341     MI   M  2005  Andres     25  0.000007)
# (('Andrew', 'F'),        region sex  year    name  count      freq
# 485669     CA   F  1984  Andrew     17  0.000005)
# (('Andrew', 'M'),         region sex  year    name  count      freq
# 944964      CT   M  1922  Andrew     73  0.000034
# 1602180     IA   M  1976  Andrew    274  0.000099
# 235230      AR   M  1941  Andrew     39  0.000017
# ...        ...  ..   ...     ...    ...       ...
# 1467004     GA   M  2018  Andrew    215  0.000073
# 5806597     VA   M  1997  Andrew    594  0.000186
# 1416385     GA   M  1966  Andrew    179  0.000055
#
# [11 rows x 6 columns])
# (('Andrey', 'M'),         region sex  year    name  count      freq
# 783272      CA   M  2020  Andrey     15  0.000005
# 732026      CA   M  2002  Andrey     11  0.000003
# 4655466     OR   M  2004  Andrey      6  0.000002)
# (('Andria', 'F'),         region sex  year    name  count      freq
# 5719546     VA   F  1982  Andria      9  0.000003
# 4690043     PA   F  1944  Andria      6  0.000002)
# (('Andy', 'M'),         region sex  year  name  count      freq
# 3128634     MO   M  1971  Andy     18  0.000006
# 3938564     NV   M  2000  Andy     22  0.000007
# 782277      CA   M  2020  Andy    175  0.000063
# ...        ...  ..   ...   ...    ...       ...
# 3948893     NV   M  2019  Andy     10  0.000003
# 2054582     IN   M  2015  Andy     12  0.000004
# 1819525     IL   M  1916  Andy     16  0.000009
#
# [8 rows x 6 columns])
# (('Anessa', 'F'),         region sex  year    name  count      freq
# 5348331     TX   F  1996  Anessa      8  0.000002)
# (('Anette', 'F'),         region sex  year    name  count      freq
# 5285710     TX   F  1964  Anette      5  0.000001)
# (('Angel', 'F'),         region sex  year   name  count      freq
# 2201686     KY   F  1992  Angel     35  0.000010
# 4957983     SC   F  1999  Angel     59  0.000018
# 3842219     NM   F  1973  Angel      9  0.000003
# 846139      CO   F  2020  Angel      8  0.000003
# 6037636     WI   F  2002  Angel     36  0.000011)
# (('Angel', 'M'),         region sex  year   name  count      freq
# 2533790     MA   M  1998  Angel     84  0.000026
# 773436      CA   M  2017  Angel   1268  0.000419)
# (('Angela', 'F'),         region sex  year    name  count      freq
# 1699        AK   F  1953  Angela      6  0.000002
# 4669131     PA   F  1915  Angela     81  0.000048
# 2965290     MN   F  2016  Angela     14  0.000004
# 1485227     HI   F  1970  Angela     37  0.000011
# 5839584     VT   F  1967  Angela     24  0.000008)
# (('Angelena', 'F'),        region sex  year      name  count      freq
# 505038     CA   F  1990  Angelena     12  0.000003)
# (('Angelic', 'F'),         region sex  year     name  count      freq
# 1740825     IL   F  1976  Angelic     10  0.000004)
# (('Angelica', 'F'),         region sex  year      name  count      freq
# 3574111     NE   F  1977  Angelica      5  0.000002
# 831069      CO   F  2006  Angelica     32  0.000009
# 1326844     GA   F  1977  Angelica      7  0.000002
# 4727989     PA   F  1982  Angelica     15  0.000005
# 923378      CT   F  1987  Angelica     21  0.000006
# 2588059     MD   F  1992  Angelica     17  0.000005
# 543501      CA   F  2001  Angelica    646  0.000196)
# (('Angelie', 'F'),         region sex  year     name  count      freq
# 5345884     TX   F  1995  Angelie      7  0.000002)
# (('Angelina', 'F'),         region sex  year      name  count      freq
# 2936293     MN   F  1979  Angelina      6  0.000002
# 2614693     MD   F  2020  Angelina     18  0.000006
# 596308      CA   F  2014  Angelina    418  0.000132
# 1966599     IN   F  1992  Angelina      7  0.000002
# 3391829     NC   F  2000  Angelina     22  0.000007
# 3721423     NJ   F  1995  Angelina     34  0.000010
# 6024766     WI   F  1984  Angelina      8  0.000003)
# (('Angelique', 'F'),         region sex  year       name  count      freq
# 1133680     FL   F  1995  Angelique     23  0.000007
# 5901825     WA   F  1993  Angelique      9  0.000003
# 2464145     MA   F  1980  Angelique     10  0.000003)
# (('Angelisse', 'F'),         region sex  year       name  count      freq
# 6219741     PR   F  2003  Angelisse      5  0.000002)
# (('Angelo', 'M'),         region sex  year    name  count      freq
# 4893938     RI   M  1916  Angelo     22  0.000012
# 2275396     KY   M  2017  Angelo      7  0.000002
# 5503380     TX   M  1980  Angelo     17  0.000005
# 3786357     NJ   M  1983  Angelo     38  0.000012
# 4151768     NY   M  1953  Angelo    156  0.000043)
# (('Angie', 'F'),         region sex  year   name  count      freq
# 3294570     MT   F  1978  Angie      7  0.000002
# 5841041     VT   F  1976  Angie      5  0.000002
# 2941191     MN   F  1987  Angie      7  0.000002
# 4295275     OH   F  1966  Angie     74  0.000023
# 5883318     WA   F  1968  Angie     36  0.000011
# 3063190     MO   F  1980  Angie     15  0.000005)
# (('Anglia', 'F'),         region sex  year    name  count      freq
# 1322858     GA   F  1972  Anglia      5  0.000002)
# (('Anibal', 'M'),         region sex  year    name  count      freq
# 675320      CA   M  1976  Anibal     14  0.000005
# 2531267     MA   M  1993  Anibal      5  0.000001)
# (('Anica', 'F'),        region sex  year   name  count      freq
# 587645     CA   F  2011  Anica      5  0.000002)
# (('Anil', 'M'),        region sex  year  name  count      freq
# 702346     CA   M  1990  Anil      7  0.000002)
# (('Anirudh', 'M'),         region sex  year     name  count      freq
# 2887001     MI   M  2006  Anirudh      7  0.000002
# 5552688     TX   M  2007  Anirudh      6  0.000002)
# (('Anisha', 'F'),         region sex  year    name  count      freq
# ...
# 3093942     MO   F  2014  Willa     12  0.000004
# 3982199     NY   F  1950  Willa      5  0.000002
# 4279599     OH   F  1950  Willa     11  0.000003
# 169919      AR   F  1917  Willa      5  0.000003
# 2186100     KY   F  1964  Willa      6  0.000002
# 1009028     DC   F  2019  Willa     10  0.000003)
# (('Willard', 'F'),         region sex  year     name  count      freq
# 3329713     NC   F  1916  Willard      7  0.000004)
# (('Willard', 'M'),         region sex  year     name  count      freq
# 5445186     TX   M  1926  Willard     46  0.000022
# 5638932     UT   M  1919  Willard     21  0.000011)
# (('Willem', 'M'),         region sex  year    name  count      freq
# 4250743     NY   M  2018  Willem      5  0.000002)
# (('William', 'F'),        region sex  year     name  count      freq
# 170444     AR   F  1918  William      5  0.000002)
# (('William', 'M'),         region sex  year     name  count      freq
# 5473044     TX   M  1954  William   2595  0.000684
# 6166319     WV   M  1952  William    948  0.000262
# 5676032     UT   M  2016  William    273  0.000088
# ...        ...  ..   ...      ...    ...       ...
# 5665721     UT   M  2002  William    185  0.000056
# 4240463     NY   M  2014  William    754  0.000238
# 1035790     DC   M  2019  William     86  0.000030
#
# [9 rows x 6 columns])
# (('Willie', 'F'),       region sex  year    name  count      freq
# 43489     AL   F  1936  Willie    333  0.000172)
# (('Willie', 'M'),         region sex  year    name  count      freq
# 141245      AL   M  1984  Willie     83  0.000026
# 1194912     FL   M  1927  Willie    316  0.000146
# 1430105     GA   M  1987  Willie    133  0.000041
# 3267300     MS   M  2000  Willie     24  0.000007
# 3875873     NM   M  1959  Willie     10  0.000003)
# (('Willis', 'M'),         region sex  year    name  count      freq
# 2389408     LA   M  1969  Willis     16  0.000005
# 2620021     MD   M  1931  Willis     13  0.000007
# 3253018     MS   M  1970  Willis      9  0.000003)
# (('Willow', 'F'),         region sex  year    name  count      freq
# 3528101     ND   F  2014  Willow     12  0.000004
# 2103992     KS   F  2008  Willow     11  0.000003)
# (('Wilma', 'F'),         region sex  year   name  count      freq
# 2431010     MA   F  1914  Wilma     11  0.000009
# 2906431     MN   F  1916  Wilma     47  0.000026)
# (('Wilson', 'M'),         region sex  year    name  count      freq
# 4906669     RI   M  1999  Wilson      7  0.000002
# 2391977     LA   M  1973  Wilson     13  0.000005
# 3104682     MO   M  1919  Wilson     16  0.000008
# 231414      AR   M  1931  Wilson      5  0.000003
# 4438518     OH   M  2008  Wilson     15  0.000004
# 2264459     KY   M  2000  Wilson      6  0.000002
# 5179374     TN   M  1952  Wilson      7  0.000002)
# (('Wilton', 'M'),         region sex  year    name  count      freq
# 4983243     SC   M  1928  Wilton     10  0.000005
# 5779015     VA   M  1948  Wilton     10  0.000003)
# (('Windell', 'M'),         region sex  year     name  count      freq
# 4998512     SC   M  1963  Windell      7  0.000002)
# (('Winfred', 'M'),         region sex  year     name  count      freq
# 5170915     TN   M  1934  Winfred     10  0.000005
# 3114485     MO   M  1941  Winfred      6  0.000003)
# (('Winifred', 'F'),         region sex  year      name  count      freq
# 2557767     MD   F  1933  Winifred      6  0.000003)
# (('Winnie', 'F'),         region sex  year    name  count      freq
# 1075285     FL   F  1927  Winnie      9  0.000004)
# (('Winona', 'F'),         region sex  year    name  count      freq
# 2723047     MI   F  1922  Winona      8  0.000004)
# (('Winston', 'M'),         region sex  year     name  count      freq
# 270663      AR   M  2020  Winston      8  0.000003
# 782517      CA   M  2020  Winston     69  0.000025
# 1889694     IL   M  2002  Winston      6  0.000002
# 4446550     OH   M  2014  Winston     15  0.000005
# 627492      CA   M  1922  Winston      6  0.000003)
# (('Winter', 'F'),        region sex  year    name  count      freq
# 103009     AL   F  2020  Winter     11  0.000004)
# (('Wren', 'M'),        region sex  year  name  count      freq
# 757945     CA   M  2011  Wren      8  0.000003)
# (('Wyatt', 'M'),         region sex  year   name  count      freq
# 5958932     WA   M  1985  Wyatt      6  0.000002
# 865969      CO   M  1975  Wyatt      5  0.000002
# 3893057     NM   M  2005  Wyatt     24  0.000007
# 3155381     MO   M  2012  Wyatt    285  0.000092
# 4565486     OK   M  2008  Wyatt    175  0.000052)
# (('Wyman', 'M'),        region sex  year   name  count      freq
# 110947     AL   M  1925  Wyman      5  0.000002)
# (('Wynell', 'F'),         region sex  year    name  count      freq
# 5249982     TX   F  1935  Wynell      8  0.000004)
# (('Wynter', 'F'),         region sex  year    name  count      freq
# 5134697     TN   F  1998  Wynter      5  0.000002)
# (('Xander', 'M'),        region sex  year    name  count      freq
# 263681     AR   M  2009  Xander     18  0.000006)
# (('Xavier', 'M'),       region sex  year    name  count      freq
# 24413     AK   M  1999  Xavier      8  0.000002)
# (('Xena', 'F'),        region sex  year  name  count      freq
# 546311     CA   F  2001  Xena      7  0.000002)
# (('Ximena', 'F'),         region sex  year    name  count      freq
# 1652956     ID   F  2018  Ximena     10  0.000003)
# (('Yael', 'F'),         region sex  year  name  count      freq
# 4024894     NY   F  1978  Yael     19  0.000007)
# (('Yaire', 'F'),         region sex  year   name  count      freq
# 3396897     NC   F  2003  Yaire      5  0.000002)
# (('Yajaira', 'F'),         region sex  year     name  count      freq
# 5144248     TN   F  2007  Yajaira      5  0.000001
# 214032      AR   F  2007  Yajaira      5  0.000001)
# (('Yamilet', 'F'),         region sex  year     name  count      freq
# 4082549     NY   F  2004  Yamilet      7  0.000002
# 3742269     NJ   F  2011  Yamilet     11  0.000004)
# (('Yandel', 'M'),         region sex  year    name  count      freq
# 1453597     GA   M  2008  Yandel     13  0.000004
# 6229284     PR   M  2002  Yandel     31  0.000009)
# (('Yaneishka', 'F'),         region sex  year       name  count      freq
# 6219567     PR   F  2003  Yaneishka      9  0.000003)
# (('Yara', 'F'),        region sex  year  name  count      freq
# 564319     CA   F  2006  Yara     27  0.000008)
# (('Yareli', 'F'),         region sex  year    name  count      freq
# 1154029     FL   F  2005  Yareli      8  0.000002)
# (('Yarelis', 'F'),         region sex  year     name  count      freq
# 3732014     NJ   F  2003  Yarelis      5  0.000002)
# (('Yaretzi', 'F'),         region sex  year     name  count      freq
# 4101523     NY   F  2012  Yaretzi     61  0.000020
# 321154      AZ   F  2007  Yaretzi     11  0.000003)
# (('Yash', 'M'),         region sex  year  name  count      freq
# 1260380     FL   M  2008  Yash      5  0.000001)
# (('Yasin', 'M'),         region sex  year   name  count      freq
# 4237242     NY   M  2012  Yasin     14  0.000005)
# (('Yasmin', 'F'),         region sex  year    name  count      freq
# 3702040     NJ   F  1975  Yasmin      5  0.000002
# 3719448     NJ   F  1993  Yasmin     14  0.000004
# 3076153     MO   F  1996  Yasmin      5  0.000002
# 4068938     NY   F  1999  Yasmin     52  0.000016)
# (('Yassin', 'M'),         region sex  year    name  count      freq
# 4227231     NY   M  2007  Yassin      8  0.000002)
# (('Yazmine', 'F'),        region sex  year     name  count      freq
# 564549     CA   F  2006  Yazmine     21  0.000006)
# (('Yehuda', 'M'),         region sex  year    name  count      freq
# 2662063     MD   M  2016  Yehuda      8  0.000003)
# (('Yesenia', 'F'),         region sex  year     name  count      freq
# 3389301     NC   F  1998  Yesenia     25  0.000008)
# (('Yetta', 'F'),         region sex  year   name  count      freq
# 2721019     MI   F  1918  Yetta      5  0.000002)
# (('Yidel', 'M'),         region sex  year   name  count      freq
# 4227385     NY   M  2007  Yidel      7  0.000002)
# (('Ying', 'F'),         region sex  year  name  count      freq
# 4054756     NY   F  1992  Ying      5  0.000001)
# (('Yisroel', 'M'),         region sex  year     name  count      freq
# 3799448     NJ   M  1999  Yisroel     22  0.000007)
# (('Yolanda', 'F'),         region sex  year     name  count      freq
# 6114493     WV   F  1924  Yolanda      6  0.000003
# 1098828     FL   F  1968  Yolanda    151  0.000048
# 899309      CT   F  1924  Yolanda     20  0.000009
# 798574      CO   F  1956  Yolanda     18  0.000005)
# (('Yolonda', 'F'),         region sex  year     name  count      freq
# 1322130     GA   F  1971  Yolonda      5  0.000002)
# (('Yoselin', 'F'),         region sex  year     name  count      freq
# 5356028     TX   F  1999  Yoselin     14  0.000004
# 1797782     IL   F  2010  Yoselin      9  0.000003)
# (('Yoshiko', 'F'),        region sex  year     name  count      freq
# 391984     CA   F  1914  Yoshiko     10  0.000008)
# (('Yousif', 'M'),        region sex  year    name  count      freq
# 763539     CA   M  2013  Yousif      9  0.000003)
# (('Yusra', 'F'),        region sex  year   name  count      freq
# 566316     CA   F  2006  Yusra      7  0.000002)
# (('Yvette', 'F'),         region sex  year    name  count      freq
# 5696175     VA   F  1946  Yvette      5  0.000002
# 3626611     NH   F  1915  Yvette     17  0.000010
# 5899903     WA   F  1991  Yvette     11  0.000003
# 2668026     ME   F  1920  Yvette     26  0.000012)
# (('Yvonne', 'F'),         region sex  year    name  count      freq
# 6019680     WI   F  1976  Yvonne     12  0.000004
# 5592486     UT   F  1933  Yvonne     11  0.000006
# 2751150     MI   F  1963  Yvonne    139  0.000037
# 3672795     NJ   F  1928  Yvonne     15  0.000007)
# (('Zachariah', 'M'),         region sex  year       name  count      freq
# 4831176     PA   M  1986  Zachariah     15  0.000005
# 6083681     WI   M  1985  Zachariah     13  0.000004
# 4653467     OR   M  2001  Zachariah     20  0.000006
# 2145876     KS   M  2003  Zachariah     11  0.000003)
# (('Zachary', 'M'),         region sex  year     name  count      freq
# 2994453     MN   M  1978  Zachary    103  0.000036
# 1063803     DE   M  1994  Zachary     85  0.000026
# 385804      AZ   M  2016  Zachary     83  0.000027
# 267878      AR   M  2016  Zachary     26  0.000008)
# (('Zachery', 'M'),         region sex  year     name  count      freq
# 3259877     MS   M  1985  Zachery     10  0.000003)
# (('Zack', 'M'),         region sex  year  name  count      freq
# 1397480     GA   M  1931  Zack      5  0.000003)
# (('Zackary', 'M'),         region sex  year     name  count      freq
# 3502022     NC   M  2018  Zackary      9  0.000003
# 3891915     NM   M  2002  Zackary      9  0.000003
# 3493925     NC   M  2012  Zackary     19  0.000006
# 2262173     KY   M  1996  Zackary     37  0.000011
# 1453280     GA   M  2008  Zackary     29  0.000009)
# (('Zackery', 'M'),         region sex  year     name  count      freq
# 750875      CA   M  2009  Zackery     31  0.000009
# 3155148     MO   M  2011  Zackery      7  0.000002)
# (('Zadyn', 'M'),         region sex  year   name  count      freq
# 2895891     MI   M  2013  Zadyn      5  0.000002)
# (('Zahara', 'F'),         region sex  year    name  count      freq
# 4096877     NY   F  2010  Zahara     21  0.000007)
# (('Zahir', 'M'),         region sex  year   name  count      freq
# 4848564     PA   M  2004  Zahir     11  0.000003)
# (('Zaiden', 'M'),         region sex  year    name  count      freq
# 264312      AR   M  2010  Zaiden     15  0.000005
# 2659118     MD   M  2013  Zaiden     16  0.000005)
# (('Zain', 'M'),         region sex  year  name  count      freq
# 4864040     PA   M  2016  Zain     15  0.000005)
# (('Zaira', 'F'),        region sex  year   name  count      freq
# 324559     AZ   F  2009  Zaira      5  0.000002)
# (('Zaire', 'M'),         region sex  year   name  count      freq
# 4251191     NY   M  2019  Zaire     38  0.000013)
# (('Zakai', 'M'),         region sex  year   name  count      freq
# 1452893     GA   M  2007  Zakai      5  0.000001)
# (('Zakary', 'M'),         region sex  year    name  count      freq
# 1672177     ID   M  1995  Zakary      6  0.000002
# 775951      CA   M  2017  Zakary      6  0.000002)
# (('Zamora', 'F'),         region sex  year    name  count      freq
# 1380905     GA   F  2017  Zamora      7  0.000002)
# (('Zander', 'M'),         region sex  year    name  count      freq
# 2716700     ME   M  2018  Zander      8  0.000003)
# (('Zandra', 'F'),        region sex  year    name  count      freq
# 492850     CA   F  1986  Zandra      6  0.000002)
# (('Zane', 'M'),         region sex  year  name  count      freq
# 5013017     SC   M  1993  Zane      8  0.000002
# 2029141     IN   M  1982  Zane     11  0.000003
# 1668528     ID   M  1981  Zane      5  0.000002)
# (('Zaniyah', 'F'),         region sex  year     name  count      freq
# 4348762     OH   F  2007  Zaniyah      5  0.000001
# 3410130     NC   F  2012  Zaniyah     15  0.000005)
# (('Zara', 'F'),         region sex  year  name  count      freq
# 5425141     TX   F  2019  Zara    118  0.000040
# 572287      CA   F  2008  Zara     59  0.000017
# 4096480     NY   F  2010  Zara     44  0.000014
# 1053998     DE   F  2020  Zara      7  0.000003)
# (('Zariah', 'F'),         region sex  year    name  count      freq
# 2112628     KS   F  2020  Zariah      8  0.000003)
# (('Zariya', 'F'),         region sex  year    name  count      freq
# 5420191     TX   F  2017  Zariya      8  0.000003)
# (('Zariyah', 'F'),         region sex  year     name  count      freq
# 3743554     NJ   F  2012  Zariyah     13  0.000004)
# (('Zavier', 'M'),         region sex  year    name  count      freq
# 5577913     TX   M  2017  Zavier     20  0.000007)
# (('Zayden', 'M'),         region sex  year    name  count      freq
# 3487826     NC   M  2007  Zayden     11  0.000003
# 6186228     WV   M  2018  Zayden     28  0.000009)
# (('Zayla', 'F'),         region sex  year   name  count      freq
# 4123357     NY   F  2020  Zayla      6  0.000002)
# (('Zayne', 'M'),         region sex  year   name  count      freq
# 5028940     SC   M  2016  Zayne      7  0.000002)
# (('Zechariah', 'M'),         region sex  year       name  count      freq
# 1885028     IL   M  1999  Zechariah     13  0.000004)
# (('Zelda', 'F'),         region sex  year   name  count      freq
# 1298483     GA   F  1937  Zelda      6  0.000003
# 2818248     MI   F  2017  Zelda     22  0.000007)
# (('Zelma', 'F'),         region sex  year   name  count      freq
# 5684121     VA   F  1920  Zelma      8  0.000004)
# (('Zenobia', 'F'),         region sex  year     name  count      freq
# 1339459     GA   F  1990  Zenobia      5  0.000001)
# (('Zeynab', 'F'),         region sex  year    name  count      freq
# 4123656     NY   F  2020  Zeynab      5  0.000002)
# (('Zhane', 'F'),         region sex  year   name  count      freq
# 4067083     NY   F  1998  Zhane     18  0.000005)
# (('Zion', 'M'),         region sex  year  name  count      freq
# 2266727     KY   M  2004  Zion      7  0.000002)
# (('Ziya', 'F'),         region sex  year  name  count      freq
# 1186936     FL   F  2019  Ziya     12  0.000004)
# (('Zoe', 'F'),         region sex  year name  count      freq
# 2724841     MI   F  1925  Zoe      5  0.000002)
# (('Zoey', 'F'),        region sex  year  name  count      freq
# 547577     CA   F  2002  Zoey    125  0.000038)
# (('Zoie', 'F'),         region sex  year  name  count      freq
# 5148245     TN   F  2011  Zoie     19  0.000006
# 2593378     MD   F  1998  Zoie      5  0.000002)
# (('Zuleyka', 'F'),         region sex  year     name  count      freq
# 1379183     GA   F  2016  Zuleyka      7  0.000002)
# (('Zuri', 'F'),         region sex  year  name  count      freq
# 6151740     WV   F  2020  Zuri      5  0.000002
# 3091955     MO   F  2012  Zuri      8  0.000003
# 520731      CA   F  1994  Zuri      8  0.000002)
# (('Zuriel', 'M'),        region sex  year    name  count      freq
# 737585     CA   M  2004  Zuriel      9  0.000003)
# (('Zvi', 'M'),         region sex  year name  count      freq
# 4244631     NY   M  2015  Zvi      5  0.000002)
# (('Zya', 'F'),        region sex  year name  count      freq
# 618071     CA   F  2019  Zya      8  0.000003)
# (('Zylah', 'F'),        region sex  year   name  count      freq
# 575860     CA   F  2008  Zylah      5  0.000001)

# %%
df['name'] = df.index.get_level_values('name_')
df['sex'] = df.index.get_level_values('sex_')
df.head()
# Out:
#               year  count      freq     name sex
# name_   sex_
# Aaden   M     2008     51  0.000015    Aaden   M
# Aahana  F     2018     26  0.000009   Aahana   F
# Aahil   M     2019      5  0.000002    Aahil   M
# Aaleyah F     2010     17  0.000005  Aaleyah   F
# Aalia   F     4033     13  0.000004    Aalia   F

# %%
df.query('name == "Chris"')
# Out:
#             year  count      freq   name sex
# name_ sex_
# Chris F     1983      5  0.000002  Chris   F
#       M     7850    239  0.000069  Chris   M

# %%
counts[('Timothy',)]
# Out:
# sex
# F       5
# M    3538
# Name: count, dtype: int64

# %%
df['istrain'] = np.random.rand(len(df)) < .9
df.head()
# Out:
#               year  count      freq     name sex  istrain
# name_   sex_
# Aaden   M     2008     51  0.000015    Aaden   M     True
# Aahana  F     2018     26  0.000009   Aahana   F     True
# Aahil   M     2019      5  0.000002    Aahil   M     True
# Aaleyah F     2010     17  0.000005  Aaleyah   F     True
# Aalia   F     4033     13  0.000004    Aalia   F     True

# %%
# A list of dicts or a dict of dicts is fastest way to create dataframe from groups of rows
# https://stackoverflow.com/users/8727339/mohit-motwani
# https://stackoverflow.com/a/57001947/623735

df_most_common = {}
for name, group in df.groupby('name'):
    row_dict = group.iloc[group['count'].argmax()].to_dict()
    df_most_common[(name, row_dict['sex'])] = row_dict
df_most_common = pd.DataFrame(df_most_common).T
df_most_common
# Out:
#           year count      freq    name sex istrain
# Aaden  M  2008    51  0.000015   Aaden   M    True
# Aahana F  2018    26  0.000009  Aahana   F    True
# Aahil  M  2019     5  0.000002   Aahil   M    True
# ...        ...   ...       ...     ...  ..     ...
# Zvi    M  2015     5  0.000002     Zvi   M    True
# Zya    F  2019     8  0.000003     Zya   F    True
# Zylah  F  2008     5  0.000001   Zylah   F    True
#
# [4025 rows x 6 columns]

# %%
df = df_with_duplicates;
for name, group in df_with_duplicates.groupby('name'):
    if len(group) > 1: 
        df.drop(group['count'].idxmin(), inplace=True)

# %%
df = df_with_duplicates
group = df.groupby('name').get_group('Chris')
group['count'].idxmax()
# Out:
# ('Chris', 'M')

# %%
df.query('name == "Chris"')
# Out:
#             year  count      freq   name sex  istrain
# name_ sex_
# Chris M     7850    239  0.000069  Chris   M     True

# %%
df_most_common['istest'] = ~df_most_common['istrain'].astype(bool)
print(df_most_common['name sex count istrain istest'.split(' ')])
# Out:
#             name sex count istrain  istest
# Aaden  M   Aaden   M    51    True   False
# Aahana F  Aahana   F    26    True   False
# Aahil  M   Aahil   M     5    True   False
# ...          ...  ..   ...     ...     ...
# Zvi    M     Zvi   M     5    True   False
# Zya    F     Zya   F     8    True   False
# Zylah  F   Zylah   F     5    True   False
#
# [4025 rows x 5 columns]

# %%
df_most_common[['istest', 'istrain']].sum() / len(df_most_common)
# Out:
# istest     0.095652
# istrain    0.904348
# dtype: float64

# %%
istest = df_most_common['istest']
istest
# Out:
# Aaden   M    False
# Aahana  F    False
# Aahil   M    False
#              ...
# Zvi     M    False
# Zya     F    False
# Zylah   F    False
# Name: istest, Length: 4025, dtype: bool

# %%
istest.sum()
# Out:
# 385

# %%
istest_idx = df_most_common[istest].index
istest_idx[:4]
# Out:
# MultiIndex([('Abelardo', 'M'),
#             ( 'Adaline', 'F'),
#             ( 'Adalynn', 'F'),
#             ( 'Addelyn', 'F')],
#            )

# %%
df['istrain'].sum() / len(df)
# Out:
# 0.9043478260869565

# %%
df['istest'] = df_most_common['istest']
df['istest'] = df['istest'].fillna(False)
df['istrain'] = ~df['istest']
df['istrain'].sum() / len(df)
# Out:
# 0.9043478260869565

# %%
df[~df['istrain'] & ~df['istest']]
# Out:
# Empty DataFrame
# Columns: [year, count, freq, name, sex, istrain, istest]
# Index: []

# %%
istrain = df['istrain']
istrain.sum() / len(istrain)
# Out:
# 0.9040993788819875

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(analyzer='char', ngram_range=(1, 3), lowercase=False)
vectorizer
# Out:
# TfidfVectorizer(analyzer='char', lowercase=False, ngram_range=(1, 3))

# %%
unique_names = df['name'][istrain].unique()
vectorizer.fit(unique_names)
vecs = vectorizer.transform(df['name'])
vecs
# Out:
# <4025x3657 sparse matrix of type '<class 'numpy.float64'>'
# 	with 57656 stored elements in Compressed Sparse Row format>

# %%
vecs = pd.DataFrame(vecs.toarray())
vecs.columns = vectorizer.get_feature_names_out()
vecs.index = df.index
print(vecs.iloc[:,:5])
# Out:
#                     A        Aa       Aad       Aah  Aal
# name_  sex_
# Aaden  M     0.193989  0.393903  0.505031  0.000000  0.0
# Aahana F     0.183496  0.372597  0.000000  0.454943  0.0
# Aahil  M     0.186079  0.377841  0.000000  0.461346  0.0
# ...               ...       ...       ...       ...  ...
# Zvi    M     0.000000  0.000000  0.000000  0.000000  0.0
# Zya    F     0.000000  0.000000  0.000000  0.000000  0.0
# Zylah  F     0.000000  0.000000  0.000000  0.000000  0.0
#
# [4025 rows x 5 columns]

# %%
import torch
torch
# Out:
# <module 'torch' from 'C:\\Users\\maria\\.conda\\envs\\nlpia2\\lib\\site-packages\\torch\\__init__.py'>

# %%
class LogisticRegressionNN(torch.nn.Module):

    def __init__(self, num_features, num_outputs=1):
         super().__init__()
         self.linear = torch.nn.Linear(num_features, num_outputs)

    def forward(self, X):
        return torch.sigmoid(self.linear(X))

# %%
def make_tensor(X):
    """ Convert numpy ndarray to torch.Tensor """
    X = getattr(X, 'values', X)
    return X if isinstance(X, torch.Tensor) else torch.Tensor(X)

def make_array(x):
    """ Convert torch.Tensor to numpy 1-D array """
    if hasattr(x, 'detach'):
        return torch.squeeze(x).detach().numpy()
    return x

# %%
num_features = vecs.shape[1]  # number of unique n-grams in our "vocabulary"
num_outputs = 1    # number of nesses (sexes) to predict, we're predicting only femaleness

# %%
from tqdm import tqdm
import time
import json
import copy

# Fraction of the tensors y_pred and y that are the same 
# (y_pred == y).sum() / len(y)
def measure_binary_accuracy(y_pred, y):
    """ Round y_pred and y then count the preds that are equal to the truth to compute fraction correct """
    y_pred = make_array(y_pred).round()
    y = make_array(y).round()
    num_correct = (y_pred == y).sum()
    return num_correct / len(y)

# %%
def measure_performance(model, X_train, X_test, y_train, y_test, criterion):
    with torch.no_grad():
        # Calculating the loss and accuracy for the train dataset
        accuracy_train = measure_binary_accuracy(model(X_train), y_train)
        outputs_test = torch.squeeze(model(X_test))
        accuracy_test = measure_binary_accuracy(outputs_test, y_test)
        loss_test = criterion(outputs_test, y_test)
        return dict(i=i, 
                    # loss_train=loss.item(),
                    accuracy_train=accuracy_train,
                    loss_test=loss_test.item(),
                    accuracy_test=accuracy_test)

# %%
model = LogisticRegressionNN(num_features=vecs.shape[1], num_outputs=1)
model
# Out:
# LogisticRegressionNN(
#   (linear): Linear(in_features=3657, out_features=1, bias=True)
# )

# %%
learning_rate = 0.05
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
optimizer
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.05
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )

# %%
df[['count']].columns
# Out:
# Index(['count'], dtype='object')

# %%
# BCE: Binary Cross Entropy
criterion = torch.nn.BCELoss(weight=torch.Tensor(df[['count']].values))
criterion
# Out:
# BCELoss()

# %%
X = vecs.values
y = (df[['sex']] == 'F').values
X_train = torch.Tensor(X[istrain])
X_test = torch.Tensor(X[~istrain])
y_train = torch.Tensor(y[istrain])
y_test = torch.Tensor(y[~istrain])

# %%
num_epochs = 200
loss_func_train = torch.nn.BCELoss(weight=torch.Tensor(df[['count']][istrain].values))
hyperparam_values ={'lr': 0.02,'momentum': 0.001}
model = LogisticRegressionNN(num_features=vecs.shape[1], num_outputs=1)
optimizer = torch.optim.SGD(model.parameters(), **hyperparam_values)
pbar_epochs = tqdm(range(num_epochs), desc='Epoch:', total=num_epochs)

for epoch in pbar_epochs:
    optimizer.zero_grad() # Setting our stored gradients equal to zero
    outputs = model(X_train)
    loss_train = loss_func_train(outputs, y_train) 
    loss_train.backward() # Computes the gradient of the given tensor w.r.t. the weights/bias
    optimizer.step() # Updates weights and biases with the optimizer (SGD)
# Out:
# Epoch:: 100%|██████████| 200/200 [00:01<00:00, 138.24it/s]

# %%
model = LogisticRegressionNN(num_features=vecs.shape[1], num_outputs=1)
optimizer = torch.optim.SGD(model.parameters(), **hyperparam_values)
loss_func_test = torch.nn.BCELoss(weight=torch.Tensor(df[['count']][~istrain].values)) 

for epoch in range(num_epochs):
    optimizer.zero_grad() 
    outputs = model(X_train)
    loss_train = loss_func_train(outputs, y_train) 
    loss_train.backward() 
    optimizer.step() 
    outputs_test = model(X_test)
    loss_test = loss_func_test(outputs_test, y_test)
    accuracy_test = measure_binary_accuracy(outputs_test, y_test)
    if epoch % 20 == 19:
        print((f'Epoch {epoch}: loss_train/test: {loss_train.item():.4f}/{loss_test.item():.4f}, accuracy_test: {accuracy_test:.4f}'))
# Out:
# Epoch 19: loss_train/test: 80.1816/75.3989, accuracy_test: 0.4275
# Epoch 39: loss_train/test: 75.0748/74.4430, accuracy_test: 0.5933
# Epoch 59: loss_train/test: 71.0529/73.7784, accuracy_test: 0.6503
# Epoch 79: loss_train/test: 67.7637/73.2873, accuracy_test: 0.6839
# Epoch 99: loss_train/test: 64.9957/72.9028, accuracy_test: 0.6891
# Epoch 119: loss_train/test: 62.6145/72.5862, accuracy_test: 0.6995
# Epoch 139: loss_train/test: 60.5302/72.3139, accuracy_test: 0.7073
# Epoch 159: loss_train/test: 58.6803/72.0716, accuracy_test: 0.7073
# Epoch 179: loss_train/test: 57.0198/71.8502, accuracy_test: 0.7202
# Epoch 199: loss_train/test: 55.5152/71.6437, accuracy_test: 0.7280

# %%
num_epochs = 100
#hyperparam_values = {'lr': 0.289}
hyperparam_values ={'lr': 0.02,'momentum': 0.001}
model = LogisticRegressionNN(num_features=vecs.shape[1], num_outputs=1)
optimizer = torch.optim.SGD(model.parameters(), **hyperparam_values)
criterion_train = torch.nn.BCELoss(weight=torch.Tensor(df[['count']][istrain].values))  # BCE: Binary Cross Entropy
criterion_test = torch.nn.BCELoss(weight=torch.Tensor(df[['count']][~istrain].values))  # BCE: Binary Cross Entropy
X = vecs.values
y = (df[['sex']] == 'F').values
X_train = torch.Tensor(X[istrain])
X_test = torch.Tensor(X[~istrain])
y_train = torch.Tensor(y[istrain])
y_test = torch.Tensor(y[~istrain])

pbar_epochs = tqdm(range(num_epochs), desc='Epoch:', total=num_epochs)
results = [None] * num_epochs
for epoch in range(num_epochs):
    optimizer.zero_grad() # Setting our stored gradients equal to zero
    outputs = model(X_train)
    loss_train = criterion_train(outputs, y_train) 
    loss_train.backward() # Computes the gradient of the given tensor w.r.t. the weights/bias
    epoch_loss_train = loss_train.item()
    optimizer.step() # Updates weights and biases with the optimizer (SGD)
    #print(f'Train loss: {np.round(loss_train.detach().numpy(), 4):0.4f}')
    outputs_test = model(X_test)
    loss_test = criterion_test(outputs_test, y_test).item()
    accuracy_test = measure_binary_accuracy(outputs_test, y_test)
    #results[epoch] = dict(loss_train=loss_train, loss_test=loss_test, accuracy_test=accuracy_test)
    if epoch % 20 == 19:
        print((f'Epoch {epoch}: loss_train/test: {loss_train:.4f}/{loss_test:.4f}, accuracy_test: {accuracy_test}'))
    #pbar_epochs.set_description(f'loss_train/test: {loss_train:.4f}/{loss_test:.4f}')
print((f'loss_train/test: {loss_train:.4f}/{loss_test:.4f}, accuracy_test: {accuracy_test}'))
# Out:
# Epoch::   0%|          | 0/100 [28:01<?, ?it/s]
# Epoch 19: loss_train/test: 80.2628/75.2845, accuracy_test: 0.43005181347150256
# Epoch 39: loss_train/test: 75.1420/74.3274, accuracy_test: 0.6139896373056994
# Epoch 59: loss_train/test: 71.1092/73.6625, accuracy_test: 0.6580310880829016
# Epoch 79: loss_train/test: 67.8115/73.1716, accuracy_test: 0.6839378238341969
# Epoch 99: loss_train/test: 65.0367/72.7877, accuracy_test: 0.6839378238341969
# Epoch 119: loss_train/test: 62.6499/72.4720, accuracy_test: 0.6968911917098446
# Epoch 139: loss_train/test: 60.5611/72.2008, accuracy_test: 0.7020725388601037
# Epoch 159: loss_train/test: 58.7074/71.9598, accuracy_test: 0.7124352331606217
# Epoch 179: loss_train/test: 57.0437/71.7398, accuracy_test: 0.7202072538860104
# Epoch 199: loss_train/test: 55.5364/71.5347, accuracy_test: 0.727979274611399
# loss_train/test: 55.5364/71.5347, accuracy_test: 0.727979274611399

# %%
# Create new majority sex column to hold the most common sex for names used for both sexes
df['majority_sex'] = df['sex']

# Overwrite the minority sex with the majority.
for name_, sex_ in df_most_common.index:
    opposite_sex = 'F' if sex_ == 'M' else 'M'
    try:
        # if you put majority_sex after .iloc this fails to overwrite data and generates warning
        df['majority_sex'].loc[(name_, opposite_sex)] = sex_
        print(f'overwrote ({name_}, {opposite_sex}) with {sex_}')
    except KeyError:
        pass

# %%
dupe_names = df[df['name'].duplicated()]['name'].values
df[df['name'].isin(dupe_names)]

# %%
weight_test = torch.Tensor(df[['count']].loc[df_most_common.index].values)
criterion_test = torch.nn.BCELoss(weight=weight_test)
criterion_test

# %%
def rand_range(min_value=0.001, max_value=1):
    scale = max_value - min_value
    return scale * np.random.rand() + min_value

# %%
def rand_range_log(min_value=0.001, max_value=1):
    min_log = np.log(min_value)
    max_log = np.log(max_value)
    return np.exp(rand_range(np.log(min_value), np.log(max_value)))

# %% [markdown]
# Create random hyperparameter table for optimizer learning_rate and momentum

# %%
# lr: learning_rate
hyperparam_ranges = dict(lr=[0.02, 1.0], momentum=[0.00001, 1.0])
hyperparam_table = []
num_attempts = 30
for i in range(num_attempts):
    hyperparam_values = dict()
    for k, v in hyperparam_ranges.items():
        hyperparam_values[k] = rand_range_log(*hyperparam_ranges[k])
    hyperparam_table.append(hyperparam_values)
pd.DataFrame(hyperparam_table)

# %%
model = LogisticRegressionNN(num_features=vecs.shape[1], num_outputs=1)
model

# %%
optimizer = torch.optim.SGD(model.parameters(), **hyperparam_table[0])
optimizer

# %%
weight_train = torch.Tensor(df['count'][istrain].values.reshape(-1, 1) / df['count'][istrain].mean())
weight_train.sum()

# %%
df['count'][istrain].values.reshape(sum(istrain), 1)

# %%
weight_train.shape

# %%
weight_test = torch.Tensor(df['count'][~istrain].values.reshape(-1, 1) / df['count'][~istrain].mean())
weight_test.sum()

# %%
# pbar = tqdm(hyperparam_table, desc='Training attempt', total=len(hyperparam_table))
num_epochs=200

t0 = time.time()
for i, hyperparam_values in enumerate(hyperparam_table):
    t1 = time.time()
    model = LogisticRegressionNN(num_features=vecs.shape[1], num_outputs=1)
    optimizer = torch.optim.SGD(model.parameters(), lr=hyperparam_values['lr'])
    # BCE: Binary Cross Entropy weighted by the number of babies with that first name and sex
    criterion_train = torch.nn.BCELoss(weight=weight_train)
    criterion_test = torch.nn.BCELoss(weight=weight_test)
    X = vecs.values
    X_train = torch.Tensor(X[istrain])
    X_test = torch.Tensor(X[~istrain])
    y_train = torch.Tensor((df[['sex']] == 'F').astype(int).values[istrain])
    y_test = torch.Tensor((df[['majority_sex']] == 'F').astype(int).values[~istrain])
    
    pbar_epochs = tqdm(range(num_epochs), desc='Epoch:', total=num_epochs)
    results = [None] * num_epochs
    for epoch in pbar_epochs:
        optimizer.zero_grad() # Setting our stored gradients equal to zero
        outputs = model(X_train)
        loss_train = criterion_train(outputs, y_train) 
        loss_train.backward() # Computes the gradient of the given tensor w.r.t. the weights/bias
        loss_train = loss_train.item()
        optimizer.step() # Updates weights and biases with the optimizer (SGD)
        # print(f'Train loss: {np.round(loss_train.detach().numpy(), 4):0.4f}')
        outputs_test = model(X_test)
        loss_test = criterion_test(outputs_test, y_test).item()
        accuracy_test = measure_binary_accuracy(outputs_test, y_test)
        results[epoch] = dict(loss_train=loss_train, loss_test=loss_test, accuracy_test=accuracy_test)
        # pbar_epochs.set_description(f'loss_train/test: {loss_train:.4f}/{loss_test:.4f}')
    t2 = time.time()
    results[-1]['time_per_attempt'] = t2 - t1
    results[-1]['total_time'] = t2 - t0
    hyperparam_table[i].update(results[-1])
    print(f'attempt {i}/{len(hyperparam_table)}')
    for k, v in hyperparam_table[i].items():
        print(f'{k}: {v:04f}')

# %%
istest = df['istest']
df['name'][istest].unique()

# %%
hyperparam_table[-1]

# %%
hyperparam_df = pd.DataFrame(hyperparam_table).sort_values('accuracy_test')
hyperparam_df

# %%
def fit(model=model, X=vecs.values, y=(df[['sex']] == 'F').values, optimizer=None,
        num_epochs=30, learning_rate=.1, criterion=criterion, optimizer=optimizer):
    pbar = tqdm(range(num_epochs), desc='Epoch', total=num_epochs)
    X_train = torch.Tensor(X[istrain])
    X_test = torch.Tensor(X[~istrain])
    y_train = torch.Tensor(y[istrain])
    y_test = torch.Tensor(y[~istrain])

    results = []
    for i in pbar:
        optimizer.zero_grad() # Setting our stored gradients equal to zero
        outputs = model(X_train)
        loss_train = criterion(outputs, y_train) 
        loss_train.backward() # Computes the gradient of the given tensor w.r.t. the weights/bias
        optimizer.step() # Updates weights and biases with the optimizer (SGD)
    return results

# %%
test_loss = hyperparam_df['loss_test']
test_accuracy = hyperparam_df['accuracy_test']
hyperparam_df.plot(x='lr', y='momentum', kind='scatter', logy=True, logx=True, grid=True, marker='o', s=100*test_accuracy**2, alpha=test_loss*.7)

# %%
results = fit()

# %%
pd.DataFrame(results)

# %%
# model.score(vecs[~istrain], y[~istrain], sample_weight=df['count'][~istrain])

# %%
# model.classes_

# %%
names = ['Dewey', 'Kemal', 'Copeland', 'Vishvesh']
ourvecs = vectorizer.transform(names)
ourvecs = pd.DataFrame.sparse.from_spmatrix(ourvecs)
ourvecs.columns = vectorizer.get_feature_names_out()
ourvecs.index = list(zip(names, 'M'*len(names)))
ourvecs

# %%
ourtensors =

# %%
names = ['Maria', 'Syndee', 'Aditi', 'Constance']
vecs = vectorizer.transform(names)
vecs = pd.DataFrame.sparse.from_spmatrix(vecs)
vecs.columns = vectorizer.get_feature_names_out()
vecs.index = list(zip(names, 'M'*len(names)))
pd.DataFrame(model.predict_proba(vecs)[:,0], index=vecs.index)

# %%
class LogisticRegressionNumpyNN(LogisticRegressionNN):

    def __init__(self, *args, **kwargs):
         super().__init__(*args, **kwargs)

    def predict_proba(self, X):
        return self.forward(make_tensor(X))
    
    def predict(self, X):
        return (np.array(self.forward(make_tesnor(X))) > 0.5).astype(int)
    
# ', '.join([v for v in dir(LogisticRegression) if v[0] != '_'])
